# %%
# !pip install --upgrade gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.8/dist-packages (4.4.0)
# Collecting gdown
#   Downloading gdown-4.6.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from gdown) (4.64.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from gdown) (2.25.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from gdown) (3.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# Successfully installed gdown-4.6.3

# %%
# !gdown --folder https://drive.google.com/drive/folders/1m0FG0Jp30C69ldQpeV2znD1sdZHA0Nni?usp=share_link
# Out:
# Retrieving folder list
# Processing file 1avtBtLVT4DmMRqhKwZtL0NbEmijLOvbq CTB_128k_slack_0.h5
# Processing file 1--K2OdkUqqsySACJVtNw1ZFom8i6s9qy CTB_128k_slack_1.h5
# Processing file 1-3_DwYPWp8StDOdjj213XSihi8XUOlD4 CTB_128k_slack_2.h5
# Processing file 1-6BLu2NayUc-eLMGdg790T-5R4QbeSpA CTB_128k_slack_3.h5
# Processing file 1-ALMlaTjBIZuDQ1Y2scLAykN7zH-mP3u CTB_128k_slack_4.h5
# Processing file 1-Drv_KwU9UDQ2V5TQuHtfvS1sYTe4heL CTB_128k_slack_5.h5
# Processing file 1-JmxSnPt5AtFiBX82qWIBwX_s7BqiN2A CTB_128k_slack_6.h5
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1avtBtLVT4DmMRqhKwZtL0NbEmijLOvbq
# To: /content/CTB/CTB_128k_slack_0.h5
# 100% 330M/330M [00:03<00:00, 93.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1--K2OdkUqqsySACJVtNw1ZFom8i6s9qy
# To: /content/CTB/CTB_128k_slack_1.h5
# 100% 330M/330M [00:04<00:00, 67.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-3_DwYPWp8StDOdjj213XSihi8XUOlD4
# To: /content/CTB/CTB_128k_slack_2.h5
# 100% 330M/330M [00:03<00:00, 89.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-6BLu2NayUc-eLMGdg790T-5R4QbeSpA
# To: /content/CTB/CTB_128k_slack_3.h5
# 100% 330M/330M [00:02<00:00, 138MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-ALMlaTjBIZuDQ1Y2scLAykN7zH-mP3u
# To: /content/CTB/CTB_128k_slack_4.h5
# 100% 330M/330M [00:03<00:00, 95.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-Drv_KwU9UDQ2V5TQuHtfvS1sYTe4heL
# To: /content/CTB/CTB_128k_slack_5.h5
# 100% 330M/330M [00:03<00:00, 92.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-JmxSnPt5AtFiBX82qWIBwX_s7BqiN2A
# To: /content/CTB/CTB_128k_slack_6.h5
# 100% 413M/413M [00:03<00:00, 105MB/s]
# Download completed

# %%
# !git clone https://github.com/vittoriopipoli/FNetCompression.git
# !mv ./FNetCompression/Classes ./
# !pip install import-ipynb
import import_ipynb
import os
# Out:
# Cloning into 'FNetCompression'...
# remote: Enumerating objects: 747, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 747 (delta 74), reused 126 (delta 67), pack-reused 600
# Receiving objects: 100% (747/747), 294.47 MiB | 18.54 MiB/s, done.
# Resolving deltas: 100% (277/277), done.
# Updating files: 100% (278/278), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting import-ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.8/dist-packages (from import-ipynb) (7.9.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from import-ipynb) (5.7.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (4.8.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (5.7.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (2.0.10)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (57.4.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->import-ipynb) (2.16.2)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.8/dist-packages (from nbformat->import-ipynb) (5.2.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->import-ipynb) (4.3.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (22.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.10.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import-ipynb) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import-ipynb) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core->nbformat->import-ipynb) (3.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import-ipynb) (3.13.0)
# Installing collected packages: jedi, import-ipynb
# Successfully installed import-ipynb-0.1.4 jedi-0.18.2

# %%
# !pip install tensorflow==2.7.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.7.0
#   Downloading tensorflow-2.7.0-cp38-cp38-manylinux2010_x86_64.whl (489.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.6/489.6 MB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (0.38.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (0.2.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (2.11.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (1.51.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (4.5.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (3.1.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (0.4.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (15.0.6.1)
# Collecting keras<2.8,>=2.7.0rc0
#   Downloading keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.2 MB/s eta 0:00:00
# Collecting flatbuffers<3.0,>=1.12
#   Downloading flatbuffers-2.0.7-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (0.30.0)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (1.21.6)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (2.2.0)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.1/463.1 KB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (1.15.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (1.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.7.0) (1.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard~=2.6->tensorflow==2.7.0) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard~=2.6->tensorflow==2.7.0) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard~=2.6->tensorflow==2.7.0) (2.16.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard~=2.6->tensorflow==2.7.0) (2.25.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard~=2.6->tensorflow==2.7.0) (57.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard~=2.6->tensorflow==2.7.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard~=2.6->tensorflow==2.7.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard~=2.6->tensorflow==2.7.0) (1.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7.0) (6.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (4.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7.0) (3.13.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7.0) (3.2.2)
# Installing collected packages: tensorflow-estimator, keras, flatbuffers, keras-preprocessing, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.1.21
#     Uninstalling flatbuffers-23.1.21:
#       Successfully uninstalled flatbuffers-23.1.21
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
# Successfully installed flatbuffers-2.0.7 keras-2.7.0 keras-preprocessing-1.1.2 tensorflow-2.7.0 tensorflow-estimator-2.7.0

# %%
from Classes.Transformer import projTransformer
from tensorflow import keras
import tensorflow as tf
import numpy as np
import pandas as pd

# %load_ext tensorboard
# Out:
# importing Jupyter notebook from /content/Classes/Transformer.ipynb
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 40.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 25.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 19.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.7.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
newDataset1_0 = pd.read_hdf("CTB/CTB_128k_slack_0.h5", key="df", mode="r")
newDataset1_1 = pd.read_hdf("CTB/CTB_128k_slack_1.h5", key="df", mode="r")
newDataset1_2 = pd.read_hdf("CTB/CTB_128k_slack_2.h5", key="df", mode="r")
newDataset1_3 = pd.read_hdf("CTB/CTB_128k_slack_3.h5", key="df", mode="r")
newDataset1_4 = pd.read_hdf("CTB/CTB_128k_slack_4.h5", key="df", mode="r")
newDataset1_5 = pd.read_hdf("CTB/CTB_128k_slack_5.h5", key="df", mode="r")
newDataset1_6 = pd.read_hdf("CTB/CTB_128k_slack_6.h5", key="df", mode="r")
dataset = pd.concat([
                            newDataset1_0,
                            newDataset1_1,
                            newDataset1_2,
                            newDataset1_3,
                            newDataset1_4,
                            newDataset1_5, 
                            newDataset1_6, 
                         ])

# %%
test  = dataset[dataset['chromosome_name']=='chr8']
val   = dataset[dataset['chromosome_name']=='chr10']
train = dataset[dataset['chromosome_name']!='chr8'][dataset['chromosome_name']!='chr10']

len(test), len(val), len(train)
# Out:
# <ipython-input-7-1db137c4ffc6>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   train = dataset[dataset['chromosome_name']!='chr8'][dataset['chromosome_name']!='chr10']
# (618, 683, 16832)

# %%
X_trainpromoter         = np.array(list(train['sequence']))
y_train                 = train['labels'].values

X_validationpromoter    = np.array(list(val['sequence']))
y_validation            = val['labels'].values

X_testpromoter         = np.array(list(test['sequence']))
y_test                 = test['labels'].values

# %%
k = 2**15
center = 128+2**16
leftpos  = center-k-1
rightpos = center+k-1
maxlen = rightpos-leftpos
leftpos, rightpos, maxlen
# Out:
# (32895, 98431, 65536)

# %%
X_train = tf.data.Dataset.from_tensor_slices(({'sequence': np.array(X_trainpromoter[:, leftpos:rightpos], dtype=np.uint8),      'target': y_train.reshape(-1,1)}))
X_val   = tf.data.Dataset.from_tensor_slices(({'sequence': np.array(X_validationpromoter[:, leftpos:rightpos], dtype=np.uint8), 'target': y_validation.reshape(-1,1)}))
X_test  = tf.data.Dataset.from_tensor_slices(({'sequence': np.array(X_testpromoter[:, leftpos:rightpos], dtype=np.uint8),       'target': y_test.reshape(-1,1)}))
cardinality = X_train.cardinality().numpy()

# %%
batch_size      = 256 # 256

# %%
X_train_tf = X_train.shuffle(cardinality*2).batch(batch_size).cache().prefetch(tf.data.AUTOTUNE).repeat()
X_val_tf   = X_val.batch(batch_size).cache().prefetch(tf.data.AUTOTUNE)
X_test_tf  = X_test.batch(batch_size).cache().prefetch(tf.data.AUTOTUNE)

# %%
model_type      = "FNET_Final"
logdir          = None
loss            = "mse"
p_enc           = "original"
pooler          = "tanh"
n_layers1       = 1
n_layers2       = 1
k_size          = "multiconv_proj" # "multiconv"
shift_freq      = True
plot_attention  = True
alternate       = None
timeskip        = False
compression     = 0.95
convDownScale   = True
tss             = None
mask_embedding  = 4
add_reg         = True
embed_dim       = 128
ff_dim          = embed_dim*4
pool_size       = 128
dense           = 128
lr              = 1e-4 # 1e-4
lr_red_epoch    = 30
reduction_factor= 5
t_rate          = 0.1    # 0.1
pad_to_0        = True

# %%
# # Clear any logs from previous runs
# !rm -rf ./logs/transformer_best_0-001/
######################################################################################################################
import tensorflow as tf
tf.keras.backend.clear_session()

resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))

strategy = tf.distribute.TPUStrategy(resolver)

with strategy.scope():
    net = projTransformer(checkpoint_dir="FNET/", model_type=model_type, n_epochs=300, batch_size=batch_size, alternate=alternate, tss=tss, pool_size=pool_size, mask_embedding=mask_embedding,
                      learning_rate=lr, patience=30, optimizer="BERTAdam", vocab_size=5, k_size = k_size, pooler=pooler, shift_freq=shift_freq, timeskip=timeskip, pad_to_0=pad_to_0,
                      lr_reduction_epoch=lr_red_epoch, maxlen=maxlen, embed_dim=embed_dim, num_heads=4, ff_dim=ff_dim, dense=dense, plot_attention=plot_attention, add_reg=add_reg,
                      dropout_rate=0.1, logdir=logdir, t_rate=t_rate, momentum=0.9, loss=loss, n_layers1=n_layers1, n_layers2=n_layers2, compression=compression, 
                      p_enc=p_enc, reduction_factor=reduction_factor)
    
########################################################################################################################
# Out:
# WARNING:tensorflow:TPU system grpc://10.64.37.50:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]
# model built
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  sequence (InputLayer)          [(None, 65536)]      0           []
#
#  token_embedding (TokenEmbeddin  ((None, 65536, 128)  640        ['sequence[0][0]']
#  g)                             , (None, 65536))
#
#  conv1d (Conv1D)                (None, 65536, 128)   98432       ['token_embedding[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 65536, 128)   147584      ['token_embedding[0][0]']
#
#  concatenate (Concatenate)      (None, 65536, 256)   0           ['conv1d[0][0]',
#                                                                   'conv1d_1[0][0]']
#
#  dense_5 (Dense)                (None, 65536, 128)   32896       ['concatenate[0][0]']
#
#  add (Add)                      (None, 65536, 128)   0           ['dense_5[0][0]',
#                                                                   'token_embedding[0][0]']
#
#  average_pooling1d (AveragePool  (None, 512, 128)    0           ['add[0][0]']
#  ing1D)
#
#  batch_normalization (BatchNorm  (None, 512, 128)    512         ['average_pooling1d[0][0]']
#  alization)
#
#  position_encoding2 (PositionEn  (None, 512, 128)    0           ['batch_normalization[0][0]']
#  coding2)
#
#  blend_buckets (blend_buckets)  (None, 512, 128)     0           ['position_encoding2[0][0]',
#                                                                   'token_embedding[0][1]']
#
#  fnet_block (FNETBlock)         (None, 26, 128)      132224      ['blend_buckets[0][0]']
#
#  add_reg (Add_REG)              (None, 27, 128)      128         ['fnet_block[0][0]']
#
#  transformer_block (Transformer  ((None, 27, 128),   396032      ['add_reg[0][0]']
#  Block)                          (None, 4, 27, 27))
#
#  tf.__operators__.getitem (Slic  (None, 128)         0           ['transformer_block[0][0]']
#  ingOpLambda)
#
#  dense (Dense)                  (None, 128)          16512       ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.math.tanh (TFOpLambda)      (None, 128)          0           ['dense[0][0]']
#
#  dense_6 (Dense)                (None, 128)          16512       ['tf.math.tanh[0][0]']
#
#  dropout_4 (Dropout)            (None, 128)          0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 128)          16512       ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 128)          0           ['dense_7[0][0]']
#
#  Regression_Output (Dense)      (None, 1)            129         ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 858,113
# Trainable params: 857,857
# Non-trainable params: 256
# __________________________________________________________________________________________________
# Parameters:
#
# checkpoint_dir  :           FNET/
# model_type  :               FNET_Final
# n_epochs  :                 300
# batch_size  :               256
# learning_rate  :            0.0001
# momentum  :                 0.9
# maxlen  :                   65536
# embed_dim  :                128
# num_heads  :                4
# ff_dim  :                   512
# vocab_size  :               5
# dense  :                    128
# dropout_rate  :             0.1
# lr_reduction_epoch  :       30
# t_rate  :                   0.1
# patience  :                 30
# optimizer  :                BERTAdam
# warmup_steps  :             1280
# shuffle  :                  True
# logdir  :                   None
# loss  :                     mse
# history  :
# n_layers1  :                1
# n_layers2  :                1
# compression  :              0.95
# plot_attention  :           True
# k_size  :                   multiconv_proj
# p_enc  :                    original
# pooler  :                   tanh
# alternate  :                None
# timeskip  :                 False
# shift_freq  :               True
# convDownScale  :            True
# tss  :                      None
# pool_size  :                128
# steps_per_epoch  :          5
# add_reg  :                  True
# reduction_factor  :         5
# mask_embedding  :           4
# w2v_init  :                 uniform
# output_neurons  :           1
# oneHot  :                   False
# n_targets  :                None
# cardinality  :              16358
# normalization  :            batch
# chimera  :                  False
# halflife  :                 False
# asymmetric  :               False
# pad_to_0  :                 True
# DNA_tags  :                 False
# c1_posenc  :                10000
# w2v_embdim  :               128
# model  :                    <keras.engine.functional.Functional object at 0x7f16d198c7c0>

# %%
X_train_d = strategy.experimental_distribute_dataset(X_train_tf)
X_val_d   = strategy.experimental_distribute_dataset(X_val_tf)
X_test_d  = strategy.experimental_distribute_dataset(X_test_tf)

# %%
net.train_model(X_train_d, 
                X_val_d, 
                True,
                cardinality,
                strategy
                )
# Out:
# cardinality 16832
# WARNING:tensorflow:6 out of the last 4767 calls to <function TPUExtended._tpu_function_creator.<locals>.tpu_function at 0x7f170c1ae550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  Epoch: 1
# 100%|██████████| 65/65 [00:39<00:00,  1.66it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 1.080 	val_loss: 0.942 	learning_rate: 3.392E-06
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 2
# 100%|██████████| 65/65 [00:35<00:00,  1.82it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 1.011 	val_loss: 0.940 	learning_rate: 6.785E-06
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 3
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.981 	val_loss: 0.936 	learning_rate: 1.018E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 4
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.930 	val_loss: 0.926 	learning_rate: 1.357E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 5
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.885 	val_loss: 0.928 	learning_rate: 1.696E-05
#
#  Epoch: 6
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.837 	val_loss: 0.986 	learning_rate: 2.035E-05
#
#  Epoch: 7
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.797 	val_loss: 0.951 	learning_rate: 2.375E-05
#
#  Epoch: 8
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.755 	val_loss: 0.865 	learning_rate: 2.714E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 9
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.723 	val_loss: 0.815 	learning_rate: 3.053E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 10
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.699 	val_loss: 0.780 	learning_rate: 3.392E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 11
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.681 	val_loss: 0.704 	learning_rate: 3.732E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 12
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.659 	val_loss: 0.696 	learning_rate: 4.071E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 13
# 100%|██████████| 65/65 [00:21<00:00,  3.04it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.641 	val_loss: 0.629 	learning_rate: 4.410E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 14
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.625 	val_loss: 0.620 	learning_rate: 4.749E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 15
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# 		train_loss: 0.602 	val_loss: 0.623 	learning_rate: 5.089E-05
#
#  Epoch: 16
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.588 	val_loss: 0.600 	learning_rate: 5.428E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 17
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# 		train_loss: 0.564 	val_loss: 0.614 	learning_rate: 5.767E-05
#
#  Epoch: 18
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# 		train_loss: 0.562 	val_loss: 0.651 	learning_rate: 6.106E-05
#
#  Epoch: 19
# 100%|██████████| 65/65 [00:21<00:00,  3.08it/s]
# 		train_loss: 0.546 	val_loss: 0.665 	learning_rate: 6.446E-05
#
#  Epoch: 20
# 100%|██████████| 65/65 [00:22<00:00,  2.91it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.535 	val_loss: 0.596 	learning_rate: 6.785E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 21
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.533 	val_loss: 0.578 	learning_rate: 7.124E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 22
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.516 	val_loss: 0.592 	learning_rate: 7.463E-05
#
#  Epoch: 23
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.510 	val_loss: 0.584 	learning_rate: 7.803E-05
#
#  Epoch: 24
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.500 	val_loss: 0.569 	learning_rate: 8.142E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 25
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.498 	val_loss: 0.562 	learning_rate: 8.481E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 26
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.489 	val_loss: 0.551 	learning_rate: 8.820E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 27
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.477 	val_loss: 0.537 	learning_rate: 9.160E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 28
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.474 	val_loss: 0.535 	learning_rate: 9.499E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 29
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# 		train_loss: 0.462 	val_loss: 0.546 	learning_rate: 9.838E-05
#
#  Epoch: 30
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# 		train_loss: 0.453 	val_loss: 0.608 	learning_rate: 8.968E-05
#
#  Epoch: 31
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.452 	val_loss: 0.508 	learning_rate: 8.934E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 32
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.442 	val_loss: 0.520 	learning_rate: 8.899E-05
#
#  Epoch: 33
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.437 	val_loss: 0.501 	learning_rate: 8.865E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 34
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.432 	val_loss: 0.512 	learning_rate: 8.831E-05
#
#  Epoch: 35
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.431 	val_loss: 0.484 	learning_rate: 8.796E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 36
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.417 	val_loss: 0.492 	learning_rate: 8.762E-05
#
#  Epoch: 37
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# 		train_loss: 0.408 	val_loss: 0.537 	learning_rate: 8.728E-05
#
#  Epoch: 38
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.408 	val_loss: 0.499 	learning_rate: 8.693E-05
#
#  Epoch: 39
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.406 	val_loss: 0.487 	learning_rate: 8.659E-05
#
#  Epoch: 40
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.400 	val_loss: 0.478 	learning_rate: 8.624E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 41
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.390 	val_loss: 0.555 	learning_rate: 8.590E-05
#  Epoch: 42
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# 		train_loss: 0.387 	val_loss: 0.509 	learning_rate: 8.556E-05
#
#  Epoch: 43
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.395 	val_loss: 0.554 	learning_rate: 8.521E-05
#
#  Epoch: 44
# 100%|██████████| 65/65 [00:21<00:00,  3.02it/s]
# 		train_loss: 0.385 	val_loss: 0.478 	learning_rate: 8.487E-05
#
#  Epoch: 45
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.382 	val_loss: 0.495 	learning_rate: 8.452E-05
#
#  Epoch: 46
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.374 	val_loss: 0.476 	learning_rate: 8.418E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 47
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# 		train_loss: 0.381 	val_loss: 0.550 	learning_rate: 8.384E-05
#
#  Epoch: 48
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# 		train_loss: 0.373 	val_loss: 0.485 	learning_rate: 8.349E-05
#
#  Epoch: 49
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# 		train_loss: 0.371 	val_loss: 0.489 	learning_rate: 8.315E-05
#
#  Epoch: 50
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.366 	val_loss: 0.492 	learning_rate: 8.280E-05
#
#  Epoch: 51
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.362 	val_loss: 0.502 	learning_rate: 8.246E-05
#  Epoch: 52
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.366 	val_loss: 0.462 	learning_rate: 8.212E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 53
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# 		train_loss: 0.364 	val_loss: 0.500 	learning_rate: 8.177E-05
#
#  Epoch: 54
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.357 	val_loss: 0.478 	learning_rate: 8.143E-05
#
#  Epoch: 55
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.356 	val_loss: 0.475 	learning_rate: 8.108E-05
#
#  Epoch: 56
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.351 	val_loss: 0.496 	learning_rate: 8.074E-05
#
#  Epoch: 57
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# 		train_loss: 0.354 	val_loss: 0.484 	learning_rate: 8.040E-05
#
#  Epoch: 58
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# 		train_loss: 0.351 	val_loss: 0.471 	learning_rate: 8.005E-05
#
#  Epoch: 59
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.345 	val_loss: 0.502 	learning_rate: 7.971E-05
#
#  Epoch: 60
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.344 	val_loss: 0.462 	learning_rate: 7.937E-05
#
#  Epoch: 61
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# 		train_loss: 0.346 	val_loss: 0.487 	learning_rate: 7.902E-05
#  Epoch: 62
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 		train_loss: 0.336 	val_loss: 0.455 	learning_rate: 7.868E-05
# ############################################ New lowest_val_loss reached #########################
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn while saving (showing 5 of 85). These functions will not be directly callable after loading.
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.8/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
#  Epoch: 63
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.330 	val_loss: 0.553 	learning_rate: 7.833E-05
#
#  Epoch: 64
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.332 	val_loss: 0.480 	learning_rate: 7.799E-05
#
#  Epoch: 65
# 100%|██████████| 65/65 [00:21<00:00,  3.04it/s]
# 		train_loss: 0.328 	val_loss: 0.575 	learning_rate: 7.765E-05
#
#  Epoch: 66
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.331 	val_loss: 0.521 	learning_rate: 7.730E-05
#
#  Epoch: 67
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# 		train_loss: 0.324 	val_loss: 0.519 	learning_rate: 7.696E-05
#
#  Epoch: 68
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.325 	val_loss: 0.513 	learning_rate: 7.661E-05
#
#  Epoch: 69
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.328 	val_loss: 0.584 	learning_rate: 7.627E-05
#
#  Epoch: 70
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.320 	val_loss: 0.590 	learning_rate: 7.593E-05
#
#  Epoch: 71
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.320 	val_loss: 0.828 	learning_rate: 7.558E-05
#  Epoch: 72
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.323 	val_loss: 0.844 	learning_rate: 7.524E-05
#
#  Epoch: 73
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.312 	val_loss: 0.894 	learning_rate: 7.489E-05
#
#  Epoch: 74
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.311 	val_loss: 0.515 	learning_rate: 7.455E-05
#
#  Epoch: 75
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.307 	val_loss: 0.570 	learning_rate: 7.421E-05
#
#  Epoch: 76
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# 		train_loss: 0.311 	val_loss: 0.537 	learning_rate: 7.386E-05
#
#  Epoch: 77
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.307 	val_loss: 0.550 	learning_rate: 7.352E-05
#
#  Epoch: 78
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# 		train_loss: 0.299 	val_loss: 0.505 	learning_rate: 7.317E-05
#
#  Epoch: 79
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# 		train_loss: 0.310 	val_loss: 0.574 	learning_rate: 7.283E-05
#
#  Epoch: 80
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# 		train_loss: 0.309 	val_loss: 0.491 	learning_rate: 7.249E-05
#
#  Epoch: 81
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.306 	val_loss: 0.529 	learning_rate: 7.214E-05
#  Epoch: 82
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.299 	val_loss: 0.519 	learning_rate: 7.180E-05
#
#  Epoch: 83
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.294 	val_loss: 0.518 	learning_rate: 7.146E-05
#
#  Epoch: 84
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.306 	val_loss: 0.525 	learning_rate: 7.111E-05
#
#  Epoch: 85
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.298 	val_loss: 0.531 	learning_rate: 7.077E-05
#
#  Epoch: 86
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# 		train_loss: 0.304 	val_loss: 0.510 	learning_rate: 7.042E-05
#
#  Epoch: 87
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.299 	val_loss: 0.484 	learning_rate: 7.008E-05
#
#  Epoch: 88
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.289 	val_loss: 0.542 	learning_rate: 6.974E-05
#
#  Epoch: 89
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.293 	val_loss: 0.487 	learning_rate: 6.939E-05
#
#  Epoch: 90
# 100%|██████████| 65/65 [00:21<00:00,  3.05it/s]
# 		train_loss: 0.274 	val_loss: 0.503 	learning_rate: 6.905E-05
#
#  Epoch: 91
# 100%|██████████| 65/65 [00:21<00:00,  3.07it/s]
# 		train_loss: 0.281 	val_loss: 0.465 	learning_rate: 6.870E-05
#  Epoch: 92
# 100%|██████████| 65/65 [00:21<00:00,  3.06it/s]
# 		train_loss: 0.278 	val_loss: 0.499 	learning_rate: 6.836E-05
#
#  Epoch: 93
# 100%|██████████| 65/65 [00:21<00:00,  3.04it/s]
# 		train_loss: 0.275 	val_loss: 0.514 	learning_rate: 6.802E-05
# End of training phase - Patience threshold reached
# Weights Restored from Lowest val_loss epoch: 62
# lowest_val_loss: 0.45500001311302185

# %%
net.evaluate_model(X_test_d, strategy=strategy)
print("")
predictions, y = net.evaluate_best_model(X_test_d, strategy=strategy)
print("")
net.plot_kde(X_test_d, strategy=strategy, predictions=predictions, y=y)
print("")
net.plot_r2(X_test_d, strategy=strategy, predictions=predictions, y=y)
print("")
# Out:
# y:  618
# pred:  618
# Test R^2 = 0.568
# Test Pearson = 0.754
# Test Spearman = 0.719
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# y:  618
# pred:  618
# Test R^2 = 0.601
# Test Pearson = 0.775
# Test Spearman = 0.736
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
